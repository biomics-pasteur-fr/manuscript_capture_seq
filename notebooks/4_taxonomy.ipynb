# %% [markdown]
# # Proportions of Covid / human /viral /bacterial content in capture seq data
#
# Author: Thomas Cokelaer 2021-2022
#
# Scripts from Sequana https://sequana.readthedocs.io
#
# Data from sequana_taxonomy pipeline and dedicated Kraken databases as described in https://github.com/biomics-pasteur-fr/manuscript_capture_seq

# %% [markdown]
# # Utility functions

# %%
# %load_ext autoreload
# %autoreload 2

import glob
import json
import pandas as pd
from sequana import MultiKrakenResults2, MultiKrakenResults
from pylab import axhline, savefig, linspace,text, gca, tight_layout

# %%
def get_files_and_samples(case, PATH="."):
    samples = [4885,4716,4660,4520,4707,4697,4676,4653,4861,4787,4688,4673,4777,4668,4489,4798,4797,4656,4544]
    samples = [str(x) for x in samples][::-1]
    filenames = [f"{PATH}/taxonomy/{case}/{sample}/summary.json" for sample in samples]
    return filenames, samples


def get_files_and_samples_meta(PATH="."):
    samples = [4885,4716,4660,4520,4707,4697,4676,4653,4861,4787,4688,4673,4777,4510,4668,4489,4798,4797,4656,4544, "Cneg_Water"]
    samples = [str(x) for x in samples][::-1]
    json_files = [f"{PATH}/taxonomy/meta/{sample}/summary.json" for sample in samples]
    csv_files = [f"{PATH}/taxonomy/meta/{sample}/kraken.csv" for sample in samples]
    return json_files, csv_files, samples

# %%
from  matplotlib import cm
L= 6
cmap="viridis"
colors6 = [cm.get_cmap(cmap)(x) for x in linspace(0.2, 1, L)][::-1]
colors5 = [colors6[0]] + colors6[2:]
colors4 = [colors6[0]] + colors6[3:]

# %% [markdown]
# # Illumina resp v2

# %%
filenames, samples = get_files_and_samples("illumina_resp_v2")      
k = MultiKrakenResults2(filenames, sample_names=samples)
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, cmap='viridis_r', sorting_method=None, fontsize=16, colors=colors6)
for x in [14.5,10.5,6.5,3.5]:
    axhline([x], lw=4, color="k")
      
ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.75), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.55), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.36), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )


tight_layout()
savefig("taxonomy_Ill_resv_v2.png", dpi=200)
savefig("taxonomy_Ill_resv_v2.pdf", dpi=200)
savefig("taxonomy_Ill_resv_v2.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # twist panviral

# %%
filenames, samples = get_files_and_samples("twist_panviral")      
k = MultiKrakenResults2(filenames, sample_names=samples)        
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, cmap='viridis_r', sorting_method=None, fontsize=16, colors=colors5)
for x in [14.5,10.5,6.5,3.5]:
    axhline([x], lw=4, color="k")
name = "twistpan"    

ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.75), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.55), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.36), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
tight_layout()

savefig(f"taxonomy_{name}.png", dpi=200)
savefig(f"taxonomy_{name}.pdf", dpi=200)
savefig(f"taxonomy_{name}.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # twist sars

# %%
filenames, samples = get_files_and_samples("twist_sars_cov2")      
k = MultiKrakenResults2(filenames, sample_names=samples)        
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, cmap='viridis_r', sorting_method=None, fontsize=16, colors=colors5)
for x in [14.5,10.5,6.5,3.5]:
    axhline([x], lw=4, color="k")
    
ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.75), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.55), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.36), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
name = "twistcov"    
tight_layout()
savefig(f"taxonomy_{name}.png", dpi=200)
savefig(f"taxonomy_{name}.pdf", dpi=200)
savefig(f"taxonomy_{name}.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # arbo

# %%
filenames, samples = get_files_and_samples("arbor")      
k = MultiKrakenResults2(filenames, sample_names=samples)        
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, cmap='viridis_r', sorting_method=None, fontsize=16, colors=colors4)
for x in [14.5,10.5,6.5,3.5]:
    axhline([x], lw=4, color="k")
name = "arbo"    
  
ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.75), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.55), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.36), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
tight_layout()

savefig(f"taxonomy_{name}.png", dpi=200)
savefig(f"taxonomy_{name}.pdf", dpi=200)
savefig(f"taxonomy_{name}.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Metagenomics

# %%
json_files, csv_file, samples = get_files_and_samples_meta()      
k = MultiKrakenResults2(json_files, sample_names=samples)        
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, cmap='viridis_r', sorting_method=None, fontsize=16, colors=colors4)
for x in [16.5,12.5,8.5,4.5,0.5]:
    axhline([x], lw=4, color="k")
name = "meta"    
ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.77), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.58), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.39), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )

savefig(f"taxonomy_{name}.png", dpi=200)
savefig(f"taxonomy_{name}.pdf", dpi=200)
savefig(f"taxonomy_{name}.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
json_files, csv_files, samples = get_files_and_samples_meta()  
k = MultiKrakenResults(csv_files, sample_names=samples)        
df = k.plot_stacked_hist("test.png", dpi=200, ytick_fontsize=12, fontsize=16)
for x in [16.5,12.5,8.5,4.5, 0.5]:
    axhline([x], lw=4, color="k")
name = "meta"    
 
ax = gca()
ax.annotate('group A', xy=(0.5, 0.90), xytext=(-0.15, 0.95), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group B', xy=(0.5, 0.90), xytext=(-0.15, 0.77), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top', rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group C', xy=(0.5, 0.90), xytext=(-0.15, 0.58), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group D', xy=(0.5, 0.90), xytext=(-0.15, 0.39), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )
ax.annotate('group E', xy=(0.5, 0.90), xytext=(-0.15, 0.20), xycoords='axes fraction', 
            fontsize=8*1.5, ha='center', va='top',  rotation=90,
            bbox=dict(boxstyle='square', fc='white')
            )

savefig(f"taxonomy_{name}_group.png", dpi=200)
savefig(f"taxonomy_{name}_group.pdf", dpi=200)
savefig(f"taxonomy_{name}_group.eps", dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
